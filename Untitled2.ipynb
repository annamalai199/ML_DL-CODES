# %%
x=10
y=10
sum=lambda x,y:x+y
print(sum(x,y))
# Out:
# 20

# %%
name = "Aarish"
age = 8

# Correct use of string formatting
print("Name= %s and Age= %d" % (name, age))

# To print "Anika" and 6 directly
print("Name= %s and Age= %d" % ("Anika", 6))
# Out:
# Name= Aarish and Age= 8
# Name= Anika and Age= 6

# %%
a="annamalai is a boy"
b="a"
if b in a:
    print("yes")
# Out:
# yes

# %%
import numpy as np
a1=np.array([[[0,1,2,3]],[[1,2,2,2]]])
print(a1)
# Out:
# [[[0 1 2 3]]
#
#  [[1 2 2 2]]]

# %%
a1.size
# Out:
# 8

# %%
import numpy as np
a1=np.array([[0,1,2,3],[1,2,3,4]])
print(a1.shape)
# Out:
# (2, 4)

# %%
a3=[1,2,3]
b3=[1,2,3]
print(a3+b3)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
import numpy as np
a1=np.array([0,1,2,3,1,2,3,4])
print(a1[1:3])
# Out:
# [1 2]
